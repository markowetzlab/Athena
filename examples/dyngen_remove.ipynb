# %%
library(dyngen)
library(tidyverse)

set.seed(1)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
backbone <- backbone_bifurcating()

config <- initialise_model(
    backbone = backbone,
    num_cells = 1000,
    num_tfs = nrow(backbone$module_info),
    num_targets = 50,
    num_hks = 50,
    verbose = FALSE,
    download_cache_dir = tools::R_user_dir("dyngen", "data"),
    simulation_params = simulation_default(
      total_time = 1000,
      census_interval = 2, 
      ssa_algorithm = ssa_etl(tau = 300/3600),
      experiment_params = simulation_type_wild_type(num_simulations = 10)
    )
  )

# %%
model <- generate_tf_network(config) %>%
            generate_feature_network() %>%
            generate_kinetics()
# Out:
# Warning message in igraph::bfs(., sample.int(ncol(realnet), 1), neimode = "all"):
# “Argument `neimode' is deprecated; use `mode' instead”

# %%
1 ^ 0
# Out:
# [1] 1

# %%
model$simulation_system$reactions[[20]]
# Out:
# Reaction: splicing_B1_TF1
#  - Propensity: splicing_rate_B1_TF1 * mol_premrna_B1_TF1
#  - Effects: mol_mrna_B1_TF1: +1, mol_premrna_B1_TF1: -1

# %%
chi_A1_TF1_A2_TF1 = str_A1_TF1_A2_TF1 * pow(mol_protein_A1_TF1/dis_A1_TF1_A2_TF1, hill_A1_TF1_A2_TF1)
chi_C2_TF1_A2_TF1 = str_C2_TF1_A2_TF1 * pow(mol_protein_C2_TF1/dis_C2_TF1_A2_TF1, hill_C2_TF1_A2_TF1)

# %%
transcription_rate_A2_TF1 * (bas_A2_TF1 - pow(ind_A2_TF1,1) + (chi_A1_TF1_A2_TF1 + ind_A2_TF1))
/
((chi_A1_TF1_A2_TF1 + 1) * (chi_C2_TF1_A2_TF1 + 1))

# %%
1 > 0
# Out:
# [1] TRUE

# %%
transcription_rate_C1_TF1 * (
    bas_C1_TF1 - pow(ind_C1_TF1,2) + 
    (chi_B1_TF1_C1_TF1 + ind_C1_TF1) *
    (chi_C1_TF1_C1_TF1 + ind_C1_TF1)
)
/
(
    (chi_B1_TF1_C1_TF1 + 1) * 
    (chi_C1_TF1_C1_TF1 + 1) * 
    (chi_C3_TF1_C1_TF1 + 1) * 
    (chi_D1_TF1_C1_TF1 + 1)
)

# %%
model$simulation_system$reactions
# Out:
# [[1]]
# Reaction: transcription_A1_TF1
#  - Propensity: chi_C3_TF1_A1_TF1 = str_C3_TF1_A1_TF1 * pow(mol_protein_C3_TF1/dis_C3_TF1_A1_TF1, hill_C3_TF1_A1_TF1); transcription_rate_A1_TF1 * (bas_A1_TF1)/((chi_C3_TF1_A1_TF1 + 1))
#  - Effects: mol_premrna_A1_TF1: +1
#
# [[2]]
# Reaction: splicing_A1_TF1
#  - Propensity: splicing_rate_A1_TF1 * mol_premrna_A1_TF1
#  - Effects: mol_mrna_A1_TF1: +1, mol_premrna_A1_TF1: -1
#
# [[3]]
# Reaction: translation_A1_TF1
#  - Propensity: translation_rate_A1_TF1 * mol_mrna_A1_TF1
#  - Effects: mol_protein_A1_TF1: +1
#
# [[4]]
# Reaction: premrna_degradation_A1_TF1
#  - Propensity: mrna_decay_rate_A1_TF1 * mol_premrna_A1_TF1
#  - Effects: mol_premrna_A1_TF1: -1
#
# [[5]]
# Reaction: mrna_degradation_A1_TF1
#  - Propensity: mrna_decay_rate_A1_TF1 * mol_mrna_A1_TF1
#  - Effects: mol_mrna_A1_TF1: -1
#
# [[6]]
# Reaction: protein_degradation_A1_TF1
#  - Propensity: protein_decay_rate_A1_TF1 * mol_protein_A1_TF1
#  - Effects: mol_protein_A1_TF1: -1
#
# ...
